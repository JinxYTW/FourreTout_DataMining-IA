# %% [markdown]
# # Import des libs

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

# %% [markdown]
# # Charger les données

# %%
X_train = np.load('X_train.npy')
y_train = np.load('y_train.npy')
X_test = np.load('X_test.npy')
y_test = np.load('y_test.npy')

print(f"X_train shape: {X_train.shape}")
# Out:
# X_train shape: (95, 3072)

# %% [markdown]
# # Appliquer la PCA

# %%
n_components = 16 
pca = PCA(n_components=n_components)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# %% [markdown]
# # Entraîner un SVM avec noyau RBF

# %%
C_value = 1.0
svm = SVC(kernel='rbf', C=C_value, gamma='scale')
svm.fit(X_train_pca, y_train)

y_pred = svm.predict(X_test_pca)

# %% [markdown]
# # Afficher la matrice de confusion

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues') 
plt.xlabel('Prédictions')
plt.ylabel('Vraies étiquettes')
plt.title('Matrice de Confusion')
plt.show()

# %% [markdown]
# # Évaluation

# %%
acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print(f'Précision globale: {acc:.4f}')
# Out:
# Précision globale: 0.5417

# %% [markdown]
# # PCA 32 élèments

# %%
n_components2 = 32  
pca2 = PCA(n_components=n_components)
X_train_pca2 = pca2.fit_transform(X_train)
X_test_pca2 = pca2.transform(X_test)

C_value = 1.0  
svm = SVC(kernel='rbf', C=C_value, gamma='scale')
svm.fit(X_train_pca2, y_train)

y_pred = svm.predict(X_test_pca2)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Prédictions')
plt.ylabel('Vraies étiquettes')
plt.title('Matrice de Confusion')
plt.show()

acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print(f'Précision globale: {acc:.4f}')
# Out:
# Précision globale: 0.5417

# %% [markdown]
# # PCA 64 élèments

# %%
n_components = 64  
pca3 = PCA(n_components=n_components)
X_train_pca3 = pca3.fit_transform(X_train)
X_test_pca3 = pca3.transform(X_test)

C_value = 1.0  
svm = SVC(kernel='rbf', C=C_value, gamma='scale')
svm.fit(X_train_pca3, y_train)

y_pred = svm.predict(X_test_pca3)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Prédictions')
plt.ylabel('Vraies étiquettes')
plt.title('Matrice de Confusion')
plt.show()

acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print(f'Précision globale: {acc:.4f}')
# Out:
# Précision globale: 0.5417

# %% [markdown]
# # Test

# %%
n_components = 128  
pca3 = PCA(n_components=n_components)
X_train_pca3 = pca3.fit_transform(X_train)
X_test_pca3 = pca3.transform(X_test)

C_value = 1.0
svm = SVC(kernel='rbf', C=C_value, gamma='scale')
svm.fit(X_train_pca3, y_train)

y_pred = svm.predict(X_test_pca3)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Prédictions')
plt.ylabel('Vraies étiquettes')
plt.title('Matrice de Confusion')
plt.show()

acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print(f'Précision globale: {acc:.4f}')
# Out:
# Précision globale: 0.5000

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

# Charger les données
X_train = np.load('X_train.npy')
y_train = np.load('y_train.npy')
X_test = np.load('X_test.npy')
y_test = np.load('y_test.npy')

# Redimensionner chaque image en un vecteur
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# Récupérer la dimension d'entrée
input_dim = X_train.shape[1]
print(f"Dimension d'entrée : {input_dim}")

# Appliquer la PCA sur chaque image
n_components = 128  # Modifier à 32 ou 64 pour tester
pca = PCA(n_components=n_components)
X_train_pca = pca.fit_transform(X_train)
X_test_pca = pca.transform(X_test)

# Entraîner un SVM avec noyau RBF
C_value = 1.0  # Modifier pour tester différentes valeurs
svm = SVC(kernel='rbf', C=C_value, gamma='scale')
svm.fit(X_train_pca, y_train)

y_pred = svm.predict(X_test_pca)

# Évaluation
acc = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print(f'Précision globale: {acc:.4f}')

# Afficher la matrice de confusion
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Prédictions')
plt.ylabel('Vraies étiquettes')
plt.title('Matrice de Confusion')
plt.show()
# Out:
# Dimension d'entrée : 3072
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 24
#      22 n_components = 128  # Modifier à 32 ou 64 pour tester
#      23 pca = PCA(n_components=n_components)
# ---> 24 X_train_pca = pca.fit_transform(X_train)
#      25 X_test_pca = pca.transform(X_test)
#      27 # Entraîner un SVM avec noyau RBF
#
# File c:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_openml
from sklearn.metrics import accuracy_score, classification_report

X_train = np.load('X_train.npy')
y_train = np.load('y_train.npy')
X_test = np.load('X_test.npy')
y_test = np.load('y_test.npy')

# 2️⃣ Normalisation des données (important pour PCA & SVM)
X_train /= 255.0

# 3️⃣ Réduire la dimension avec PCA
pca = PCA(n_components=16)  # Réduire à 50 dimensions (optimisé pour classification)
X_pca = pca.fit_transform(X_train)



# 5️⃣ Entraîner un classifieur SVM
svm_model = SVC(kernel='rbf', C=10)  # RBF est souvent plus performant sur MNIST
svm_model.fit(X_train, y_train)

# 6️⃣ Prédictions et évaluation
y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy (SVM après PCA): {accuracy * 100:.2f}%")
print(classification_report(y_test, y_pred))

# 7️⃣ Visualisation en 2D si PCA réduit à 2 composants
pca_2d = PCA(n_components=2)
X_pca_2d = pca_2d.fit_transform(X_train)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_pca_2d[:, 0], y=X_pca_2d[:, 1], hue=y_train, palette="tab10", alpha=0.5)
plt.xlabel("Composante Principale 1")
plt.ylabel("Composante Principale 2")
plt.title("Visualisation des chiffres MNIST en 2D après PCA")
plt.legend(title="Chiffres")
plt.show()
# Out:
# Test Accuracy (SVM après PCA): 8.33%
#               precision    recall  f1-score   support
#
#       banane       0.00      0.00      0.00         5
#       cerise       0.08      1.00      0.15         2
#    mirabelle       0.00      0.00      0.00         5
#       orange       0.00      0.00      0.00         3
#        pomme       0.00      0.00      0.00         6
#        prune       0.00      0.00      0.00         3
#
#     accuracy                           0.08        24
#    macro avg       0.01      0.17      0.03        24
# weighted avg       0.01      0.08      0.01        24
# c:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
